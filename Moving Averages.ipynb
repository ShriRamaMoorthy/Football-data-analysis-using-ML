# %%
# use pandas to load and manipulate the data, matplotlib to plot
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tottenham prem xg.csv')

# %%
df.head()
# Out:
#          Date           Time        Round  Day Venue Result   GF   GA  \
# 0  13-09-2020  16:30 (09:30)  Matchweek 1  Sun  Home      L  0.0  1.0
# 1  20-09-2020  12:00 (05:00)  Matchweek 2  Sun  Away      W  5.0  2.0
# 2  27-09-2020  14:00 (07:00)  Matchweek 3  Sun  Home      D  1.0  1.0
# 3  04-10-2020  16:30 (09:30)  Matchweek 4  Sun  Away      W  6.0  1.0
# 4  18-10-2020  16:30 (09:30)  Matchweek 5  Sun  Home      D  3.0  3.0
#
#          Opponent   xG  xGA  Poss  Attendance      Captain   Formation  \
# 0         Everton  1.0  1.4  51.0         NaN  Hugo Lloris     4-2-3-1
# 1     Southampton  2.5  1.5  49.0         NaN  Hugo Lloris  04-03-2003
# 2   Newcastle Utd  2.3  1.0  66.0         NaN  Hugo Lloris     4-2-3-1
# 3  Manchester Utd  3.8  0.9  62.0         NaN  Hugo Lloris  04-03-2003
# 4        West Ham  1.2  2.1  51.0         NaN  Hugo Lloris     4-2-3-1
#
#            Referee  Match Report  Notes
# 0  Martin Atkinson  Match Report    NaN
# ...

# %%
df=df.fillna(0)

# %%
df=df.drop(['Attendance','Notes'],axis=1)

# %%
df.head()
# Out:
#          Date           Time        Round  Day Venue Result   GF   GA  \
# 0  13-09-2020  16:30 (09:30)  Matchweek 1  Sun  Home      L  0.0  1.0
# 1  20-09-2020  12:00 (05:00)  Matchweek 2  Sun  Away      W  5.0  2.0
# 2  27-09-2020  14:00 (07:00)  Matchweek 3  Sun  Home      D  1.0  1.0
# 3  04-10-2020  16:30 (09:30)  Matchweek 4  Sun  Away      W  6.0  1.0
# 4  18-10-2020  16:30 (09:30)  Matchweek 5  Sun  Home      D  3.0  3.0
#
#          Opponent   xG  xGA  Poss      Captain   Formation          Referee  \
# 0         Everton  1.0  1.4  51.0  Hugo Lloris     4-2-3-1  Martin Atkinson
# 1     Southampton  2.5  1.5  49.0  Hugo Lloris  04-03-2003      David Coote
# 2   Newcastle Utd  2.3  1.0  66.0  Hugo Lloris     4-2-3-1     Peter Bankes
# 3  Manchester Utd  3.8  0.9  62.0  Hugo Lloris  04-03-2003   Anthony Taylor
# 4        West Ham  1.2  2.1  51.0  Hugo Lloris     4-2-3-1     Paul Tierney
#
#    Match Report
# 0  Match Report
# 1  Match Report
# 2  Match Report
# 3  Match Report
# ...

# %%
df['match'] = range(1,39)

# %%
df['xgSMA'] = df['xG'].rolling(window=2).mean()
df['xgaSMA'] = df['xGA'].rolling(window=2).mean()

# %%
plt.plot(df.match,df.xgSMA,color='blue')
plt.plot(df.match,df.xgaSMA,color='red')

plt.xlabel("Matchdays")
plt.ylabel("Quality of chance")

plt.legend(['xG of Tottenham Hotspur F.C','xGA of Tottenham Hotspur F.C'])
